# %%
import os
import glob

def rename_images_to_sequential(folder_path, prefix='image', ext='jpg'):
    # 모든 jpg 파일 경로 가져오기
    image_paths = sorted(glob.glob(os.path.join(folder_path, f'*.{ext}')))

    # 리네이밍
    for idx, old_path in enumerate(image_paths):
        new_filename = f"{prefix}_{idx+1:04d}.{ext}"
        new_path = os.path.join(folder_path, new_filename)
        os.rename(old_path, new_path)
        # print(f"{os.path.basename(old_path)} → {new_filename}")

# 실행
rename_images_to_sequential("/home/najo/NAS/Computer_Vision/image")

# %%
import cv2
import numpy as np
import os
import glob
import shutil
import open3d as o3d

# =========================
# 조절 가능한 파라미터 (Adjustable Parameters)
# =========================
image_folder = '/home/najo/NAS/Computer_Vision/image'  # 이미지 폴더 경로 (필요시 변경)
output_folder = './sfm_output'                         # 결과 저장 폴더
SUPPORTED_EXT = ('.jpg', '.JPG')
LOWE_RATIO_THRESH = 0.95                            # Lowe의 ratio test 임계값
MIN_MATCH_COUNT = 5                                       # 초기 매칭 최소 개수
MIN_PNP_POINTS = 4                                   # PnP 최소 대응점 수 (최소 4개)
RANSAC_THRESHOLD = 3.0                               # Essential Matrix 추정 RANSAC 임계값

# 추가 최적화 파라미터: Outlier Removal (3D 포인트 클라우드 필터링)
OUTLIER_NB_NEIGHBORS = 30
OUTLIER_STD_RATIO = 3.0

# =========================
# 출력 폴더 생성
# =========================
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# =========================
# 이미지 로딩 및 K 행렬 추정 (첫 이미지 기준)
# =========================
img_files = sorted(glob.glob(os.path.join(image_folder, '*')))[::-1]
img_files = [f for f in img_files if f.lower().endswith(SUPPORTED_EXT)]
if len(img_files) < 2:
    print("Error: Need at least two images for SfM.")
    exit()

images = []
for f in img_files:
    img = cv2.imread(f)
    if img is not None:
        images.append(img)
print(f"Loaded {len(images)} images.")

K_path = os.path.join(image_folder, 'K.txt')
K = np.loadtxt(K_path)

# =========================
# SIFT를 통한 특징점 추출
# =========================
sift = cv2.SIFT_create()
keypoints_list = []
descriptors_list = []
print("Extracting SIFT features...")
for i, img in enumerate(images):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    kp, des = sift.detectAndCompute(gray, None)
    keypoints_list.append(kp)
    descriptors_list.append(des)
    print(f"Image {i}: {len(kp)} features")

# =========================
# FLANN 기반 매칭 (Lowe's ratio test 적용)
# =========================
FLANN_INDEX_KDTREE = 1
index_params = dict(algorithm=FLANN_INDEX_KDTREE, trees=5)
search_params = dict(checks=50)
flann = cv2.FlannBasedMatcher(index_params, search_params)
all_matches = {}
num_images = len(images)
print("Matching features between image pairs...")
for i in range(num_images):
    for j in range(i + 1, num_images):
        if descriptors_list[i] is not None and descriptors_list[j] is not None:
            matches = flann.knnMatch(descriptors_list[i], descriptors_list[j], k=2)
            good_matches = []
            for m, n in matches:
                if m.distance < LOWE_RATIO_THRESH * n.distance:
                    good_matches.append(m)
            if len(good_matches) > MIN_MATCH_COUNT:
                all_matches[(i, j)] = good_matches
                print(f"Matches between image {i} and {j}: {len(good_matches)}")

# =========================
# 초기 이미지 쌍 선택 및 초기화 (Step I & II)
# =========================
best_pair = None
max_matches = 0
for pair, matches in all_matches.items():
    if len(matches) > max_matches:
        max_matches = len(matches)
        best_pair = pair
if best_pair is None:
    print("Error: No suitable initial pair found.")
    exit()
i1, i2 = best_pair
initial_matches = all_matches[best_pair]
print(f"Selected initial pair: Image {i1} and {i2} with {len(initial_matches)} matches")

pts1 = np.float32([keypoints_list[i1][m.queryIdx].pt for m in initial_matches]).reshape(-1, 1, 2)
pts2 = np.float32([keypoints_list[i2][m.trainIdx].pt for m in initial_matches]).reshape(-1, 1, 2)

# Essential Matrix 추정 (RANSAC 적용)
E, mask_e = cv2.findEssentialMat(pts1, pts2, K, method=cv2.RANSAC, prob=0.999, threshold=RANSAC_THRESHOLD)
if E is None:
    print("Error: Could not estimate Essential Matrix.")
    exit()
inlier_matches = [m for i, m in enumerate(initial_matches) if mask_e[i]]
pts1_inlier = np.float32([keypoints_list[i1][m.queryIdx].pt for m in inlier_matches]).reshape(-1, 2)
pts2_inlier = np.float32([keypoints_list[i2][m.trainIdx].pt for m in inlier_matches]).reshape(-1, 2)
print(f"Essential Matrix inliers: {len(pts1_inlier)}")

# 포즈 복원 (recoverPose)
points, R, t, mask_rp = cv2.recoverPose(E, pts1_inlier, pts2_inlier, K)
print(f"Recovered pose: {points} points in front of cameras")

# 삼각측량을 통한 초기 3D 포인트 복원 (Step IV)
P1 = K @ np.hstack((np.eye(3), np.zeros((3, 1))))
P2 = K @ np.hstack((R, t))
points4D = cv2.triangulatePoints(P1, P2, pts1_inlier.T, pts2_inlier.T)
points3D = (points4D / points4D[3])[:3].T
print(f"Triangulated {len(points3D)} 3D points.")

# 데이터 구조 초기화 (색상 정보 포함)
camera_poses = {}
camera_poses[i1] = (np.eye(3), np.zeros((3, 1)))
camera_poses[i2] = (R, t)
registered_images = {i1, i2}
point_cloud = {}
point_visibility = {}
keypoint_to_3d = {}
point_colors = {}  # 각 3D 포인트의 색상 (RGB, 0~1)
for idx, m in enumerate(inlier_matches):
    pt_idx = len(point_cloud)
    point_cloud[pt_idx] = points3D[idx]
    kp_idx1 = m.queryIdx
    kp_idx2 = m.trainIdx
    point_visibility[pt_idx] = [(i1, kp_idx1), (i2, kp_idx2)]
    keypoint_to_3d[(i1, kp_idx1)] = pt_idx
    keypoint_to_3d[(i2, kp_idx2)] = pt_idx
    # 색상 정보: 초기 이미지(i1)에서 keypoint 위치의 색상 (BGR -> RGB, 정규화)
    x, y = keypoints_list[i1][kp_idx1].pt
    color_bgr = images[i1][int(round(y)), int(round(x))]
    color_rgb = color_bgr[::-1] / 255.0
    point_colors[pt_idx] = color_rgb

# 중간 결과 저장 함수 (각 뷰별 ply 파일 저장)
def save_intermediate_results(view_count):
    pcd = o3d.geometry.PointCloud()
    pts = np.array([pt for pt in point_cloud.values()])
    pcd.points = o3d.utility.Vector3dVector(pts)
    colors = np.array([point_colors[pt] for pt in sorted(point_cloud.keys())])
    pcd.colors = o3d.utility.Vector3dVector(colors)
    ply_filename = os.path.join(output_folder, f'point_cloud_{view_count}view.ply')
    o3d.io.write_point_cloud(ply_filename, pcd)
    print(f"Intermediate point cloud saved to {ply_filename}")

# =========================
# 초기 2-view 결과 저장 (Step I-II 완료)
# =========================
save_intermediate_results(len(registered_images))
# =========================
# Growing Step: 남은 이미지들에 대해 PnP를 통한 카메라 포즈 추정 (Step V)
# =========================
remaining_images = set(range(num_images)) - registered_images
while remaining_images:
    best_next_img = -1
    best_match_count = 0
    best_obj_pts = []
    best_img_pts = []
    for next_idx in remaining_images:
        temp_obj_pts = []
        temp_img_pts = []
        for reg_idx in registered_images:
            pair = tuple(sorted((next_idx, reg_idx)))
            if pair in all_matches:
                for m in all_matches[pair]:
                    if pair[0] == next_idx:
                        kp_idx_next = m.queryIdx
                        kp_idx_reg = m.trainIdx
                    else:
                        kp_idx_next = m.trainIdx
                        kp_idx_reg = m.queryIdx
                    if (reg_idx, kp_idx_reg) in keypoint_to_3d:
                        pt_idx = keypoint_to_3d[(reg_idx, kp_idx_reg)]
                        if pt_idx in point_cloud:
                            temp_obj_pts.append(point_cloud[pt_idx])
                            temp_img_pts.append(keypoints_list[next_idx][kp_idx_next].pt)
        if len(temp_obj_pts) > best_match_count and len(temp_obj_pts) >= MIN_PNP_POINTS:
            best_match_count = len(temp_obj_pts)
            best_next_img = next_idx
            best_obj_pts = np.array(temp_obj_pts, dtype=np.float32)
            best_img_pts = np.array(temp_img_pts, dtype=np.float32)
    if best_next_img == -1:
        print("No more images can be registered. Stopping.")
        break
    print(f"Adding Image {best_next_img} with {best_match_count} correspondences.")
    if len(best_obj_pts) < 4:
        print(f"Not enough points for PnP for Image {best_next_img}, skipping.")
        remaining_images.remove(best_next_img)
        continue
    ret, rvec, tvec, inliers = cv2.solvePnPRansac(
        best_obj_pts, best_img_pts, K, None,
        iterationsCount=500, reprojectionError=10.0, confidence=0.99
    )
    if ret:
        R_new, _ = cv2.Rodrigues(rvec)
        camera_poses[best_next_img] = (R_new, tvec)
        registered_images.add(best_next_img)
        remaining_images.remove(best_next_img)
        print(f"Image {best_next_img} registered successfully.")
        save_intermediate_results(len(registered_images))
    else:
        print(f"PnP failed for Image {best_next_img}. Removing from candidates.")
        remaining_images.remove(best_next_img)

# 최종 결과 저장 (현재까지의 3D 포인트 클라우드)
final_ply_filename = os.path.join(output_folder, 'point_cloud_final.ply')
pcd = o3d.geometry.PointCloud()
final_pts = np.array([pt for pt in point_cloud.values()])
pcd.points = o3d.utility.Vector3dVector(final_pts)
final_colors = np.array([point_colors[pt] for pt in sorted(point_cloud.keys())])
pcd.colors = o3d.utility.Vector3dVector(final_colors)
pcd, ind = pcd.remove_statistical_outlier(nb_neighbors=OUTLIER_NB_NEIGHBORS, std_ratio=OUTLIER_STD_RATIO)
o3d.io.write_point_cloud(final_ply_filename, pcd)
print(f"Final colored point cloud saved to {final_ply_filename}")

# 모든 이미지에 대해 ply 파일 생성 (등록되지 않은 이미지도 포함)
for i in range(num_images):
    ply_filename = os.path.join(output_folder, f'point_cloud_{i+1}view.ply')
    if i in registered_images:
        # 등록된 이미지: 이미 중간 결과로 저장되어 있을 수 있음. 여기서는 덮어쓰기.
        shutil.copy(final_ply_filename, ply_filename)
        print(f"Saved ply for registered image {i} as {ply_filename}")
    else:
        # 미등록 이미지는 최종 ply 파일을 복사하여 사용
        new_filename = os.path.join(output_folder, f'point_cloud_{i+1}view_failed.ply')
        shutil.copy(final_ply_filename, new_filename)
        print(f"Saved ply for unregistered image {i} as {new_filename}")

print("\nSfM process finished (without bundle adjustment, full ply saving for all images).")
# Out:
# Loaded 32 images.
# Extracting SIFT features...
# Image 0: 320 features
# Image 1: 1317 features
# Image 2: 1226 features
# Image 3: 832 features
# Image 4: 779 features
# Image 5: 843 features
# Image 6: 382 features
# Image 7: 328 features
# Image 8: 399 features
# Image 9: 1317 features
# Image 10: 345 features
# Image 11: 428 features
# Image 12: 348 features
# Image 13: 239 features
# Image 14: 502 features
# Image 15: 353 features
# Image 16: 298 features
# Image 17: 340 features
# Image 18: 232 features
# Image 19: 277 features
# Image 20: 1067 features
# Image 21: 605 features
# Image 22: 585 features
# Image 23: 267 features
# Image 24: 440 features
# Image 25: 665 features
# Image 26: 622 features
# Image 27: 376 features
# Image 28: 651 features
# Image 29: 409 features
# Image 30: 353 features
# Image 31: 342 features
# Matching features between image pairs...
# Matches between image 0 and 1: 155
# Matches between image 0 and 2: 141
# Matches between image 0 and 3: 164
# Matches between image 0 and 4: 163
# Matches between image 0 and 5: 167
# Matches between image 0 and 6: 245
# Matches between image 0 and 7: 214
# Matches between image 0 and 8: 193
# Matches between image 0 and 9: 160
# Matches between image 0 and 10: 178
# Matches between image 0 and 11: 157
# Matches between image 0 and 12: 149
# Matches between image 0 and 13: 167
# Matches between image 0 and 14: 172
# Matches between image 0 and 15: 161
# Matches between image 0 and 16: 163
# Matches between image 0 and 17: 167
# Matches between image 0 and 18: 151
# Matches between image 0 and 19: 152
# Matches between image 0 and 20: 155
# Matches between image 0 and 21: 169
# Matches between image 0 and 22: 152
# Matches between image 0 and 23: 160
# Matches between image 0 and 24: 149
# Matches between image 0 and 25: 153
# Matches between image 0 and 26: 148
# Matches between image 0 and 27: 167
# Matches between image 0 and 28: 175
# Matches between image 0 and 29: 162
# Matches between image 0 and 30: 203
# Matches between image 0 and 31: 213
# Matches between image 1 and 2: 780
# Matches between image 1 and 3: 706
# Matches between image 1 and 4: 678
# Matches between image 1 and 5: 678
# Matches between image 1 and 6: 698
# Matches between image 1 and 7: 674
# Matches between image 1 and 8: 655
# Matches between image 1 and 9: 1317
# Matches between image 1 and 10: 710
# Matches between image 1 and 11: 700
# Matches between image 1 and 12: 721
# Matches between image 1 and 13: 705
# Matches between image 1 and 14: 724
# Matches between image 1 and 15: 715
# Matches between image 1 and 16: 718
# Matches between image 1 and 17: 748
# Matches between image 1 and 18: 698
# Matches between image 1 and 19: 704
# Matches between image 1 and 20: 892
# Matches between image 1 and 21: 724
# Matches between image 1 and 22: 834
# Matches between image 1 and 23: 677
# Matches between image 1 and 24: 710
# Matches between image 1 and 25: 814
# Matches between image 1 and 26: 758
# Matches between image 1 and 27: 711
# Matches between image 1 and 28: 702
# Matches between image 1 and 29: 702
# Matches between image 1 and 30: 700
# Matches between image 1 and 31: 680
# Matches between image 2 and 3: 779
# Matches between image 2 and 4: 657
# Matches between image 2 and 5: 674
# Matches between image 2 and 6: 661
# Matches between image 2 and 7: 659
# Matches between image 2 and 8: 643
# Matches between image 2 and 9: 737
# Matches between image 2 and 10: 646
# Matches between image 2 and 11: 673
# Matches between image 2 and 12: 678
# Matches between image 2 and 13: 687
# Matches between image 2 and 14: 692
# Matches between image 2 and 15: 696
# Matches between image 2 and 16: 695
# Matches between image 2 and 17: 731
# Matches between image 2 and 18: 692
# Matches between image 2 and 19: 684
# Matches between image 2 and 20: 703
# Matches between image 2 and 21: 797
# Matches between image 2 and 22: 759
# Matches between image 2 and 23: 704
# Matches between image 2 and 24: 755
# Matches between image 2 and 25: 706
# Matches between image 2 and 26: 651
# Matches between image 2 and 27: 662
# Matches between image 2 and 28: 674
# Matches between image 2 and 29: 642
# Matches between image 2 and 30: 667
# Matches between image 2 and 31: 659
# Matches between image 3 and 4: 491
# Matches between image 3 and 5: 447
# Matches between image 3 and 6: 424
# Matches between image 3 and 7: 463
# Matches between image 3 and 8: 443
# Matches between image 3 and 9: 434
# Matches between image 3 and 10: 447
# Matches between image 3 and 11: 476
# Matches between image 3 and 12: 479
# Matches between image 3 and 13: 495
# Matches between image 3 and 14: 523
# Matches between image 3 and 15: 543
# Matches between image 3 and 16: 509
# Matches between image 3 and 17: 507
# Matches between image 3 and 18: 480
# Matches between image 3 and 19: 461
# Matches between image 3 and 20: 441
# Matches between image 3 and 21: 531
# Matches between image 3 and 22: 466
# Matches between image 3 and 23: 443
# Matches between image 3 and 24: 495
# Matches between image 3 and 25: 446
# Matches between image 3 and 26: 439
# Matches between image 3 and 27: 538
# Matches between image 3 and 28: 484
# Matches between image 3 and 29: 446
# Matches between image 3 and 30: 456
# Matches between image 3 and 31: 452
# Matches between image 4 and 5: 467
# Matches between image 4 and 6: 388
# Matches between image 4 and 7: 407
# Matches between image 4 and 8: 428
# Matches between image 4 and 9: 370
# Matches between image 4 and 10: 403
# Matches between image 4 and 11: 563
# Matches between image 4 and 12: 502
# Matches between image 4 and 13: 460
# Matches between image 4 and 14: 553
# Matches between image 4 and 15: 450
# Matches between image 4 and 16: 427
# Matches between image 4 and 17: 420
# Matches between image 4 and 18: 404
# Matches between image 4 and 19: 413
# Matches between image 4 and 20: 400
# Matches between image 4 and 21: 428
# Matches between image 4 and 22: 405
# Matches between image 4 and 23: 410
# Matches between image 4 and 24: 404
# Matches between image 4 and 25: 379
# Matches between image 4 and 26: 379
# Matches between image 4 and 27: 451
# Matches between image 4 and 28: 621
# Matches between image 4 and 29: 485
# Matches between image 4 and 30: 406
# Matches between image 4 and 31: 429
# Matches between image 5 and 6: 427
# Matches between image 5 and 7: 432
# Matches between image 5 and 8: 423
# Matches between image 5 and 9: 393
# Matches between image 5 and 10: 453
# Matches between image 5 and 11: 465
# Matches between image 5 and 12: 464
# Matches between image 5 and 13: 446
# Matches between image 5 and 14: 465
# Matches between image 5 and 15: 441
# Matches between image 5 and 16: 446
# Matches between image 5 and 17: 446
# Matches between image 5 and 18: 445
# Matches between image 5 and 19: 458
# Matches between image 5 and 20: 415
# Matches between image 5 and 21: 433
# Matches between image 5 and 22: 432
# Matches between image 5 and 23: 429
# Matches between image 5 and 24: 437
# Matches between image 5 and 25: 425
# Matches between image 5 and 26: 420
# Matches between image 5 and 27: 466
# Matches between image 5 and 28: 504
# Matches between image 5 and 29: 562
# Matches between image 5 and 30: 451
# Matches between image 5 and 31: 438
# Matches between image 6 and 7: 272
# Matches between image 6 and 8: 227
# Matches between image 6 and 9: 182
# Matches between image 6 and 10: 219
# Matches between image 6 and 11: 205
# Matches between image 6 and 12: 182
# Matches between image 6 and 13: 199
# Matches between image 6 and 14: 207
# Matches between image 6 and 15: 224
# Matches between image 6 and 16: 199
# Matches between image 6 and 17: 205
# Matches between image 6 and 18: 198
# Matches between image 6 and 19: 210
# Matches between image 6 and 20: 193
# Matches between image 6 and 21: 193
# Matches between image 6 and 22: 187
# Matches between image 6 and 23: 191
# Matches between image 6 and 24: 202
# Matches between image 6 and 25: 210
# Matches between image 6 and 26: 205
# Matches between image 6 and 27: 188
# Matches between image 6 and 28: 196
# Matches between image 6 and 29: 204
# Matches between image 6 and 30: 233
# Matches between image 6 and 31: 253
# Matches between image 7 and 8: 178
# Matches between image 7 and 9: 172
# Matches between image 7 and 10: 179
# Matches between image 7 and 11: 160
# Matches between image 7 and 12: 156
# Matches between image 7 and 13: 181
# Matches between image 7 and 14: 167
# Matches between image 7 and 15: 185
# Matches between image 7 and 16: 187
# Matches between image 7 and 17: 182
# Matches between image 7 and 18: 173
# Matches between image 7 and 19: 180
# Matches between image 7 and 20: 162
# Matches between image 7 and 21: 164
# Matches between image 7 and 22: 158
# Matches between image 7 and 23: 168
# Matches between image 7 and 24: 165
# Matches between image 7 and 25: 155
# Matches between image 7 and 26: 166
# Matches between image 7 and 27: 171
# Matches between image 7 and 28: 179
# Matches between image 7 and 29: 191
# Matches between image 7 and 30: 184
# Matches between image 7 and 31: 193
# Matches between image 8 and 9: 204
# Matches between image 8 and 10: 222
# Matches between image 8 and 11: 221
# Matches between image 8 and 12: 220
# Matches between image 8 and 13: 214
# Matches between image 8 and 14: 226
# Matches between image 8 and 15: 207
# Matches between image 8 and 16: 203
# Matches between image 8 and 17: 206
# Matches between image 8 and 18: 204
# Matches between image 8 and 19: 210
# Matches between image 8 and 20: 218
# Matches between image 8 and 21: 208
# Matches between image 8 and 22: 193
# Matches between image 8 and 23: 207
# Matches between image 8 and 24: 220
# Matches between image 8 and 25: 200
# Matches between image 8 and 26: 203
# Matches between image 8 and 27: 206
# Matches between image 8 and 28: 236
# Matches between image 8 and 29: 229
# Matches between image 8 and 30: 266
# Matches between image 8 and 31: 294
# Matches between image 9 and 10: 711
# Matches between image 9 and 11: 715
# Matches between image 9 and 12: 748
# Matches between image 9 and 13: 693
# Matches between image 9 and 14: 725
# Matches between image 9 and 15: 706
# Matches between image 9 and 16: 707
# Matches between image 9 and 17: 736
# Matches between image 9 and 18: 698
# Matches between image 9 and 19: 708
# Matches between image 9 and 20: 895
# Matches between image 9 and 21: 711
# Matches between image 9 and 22: 840
# Matches between image 9 and 23: 690
# Matches between image 9 and 24: 726
# Matches between image 9 and 25: 804
# Matches between image 9 and 26: 752
# Matches between image 9 and 27: 708
# Matches between image 9 and 28: 695
# Matches between image 9 and 29: 712
# Matches between image 9 and 30: 692
# Matches between image 9 and 31: 682
# Matches between image 10 and 11: 198
# Matches between image 10 and 12: 202
# Matches between image 10 and 13: 175
# Matches between image 10 and 14: 176
# Matches between image 10 and 15: 180
# Matches between image 10 and 16: 172
# Matches between image 10 and 17: 176
# Matches between image 10 and 18: 164
# Matches between image 10 and 19: 159
# Matches between image 10 and 20: 157
# Matches between image 10 and 21: 147
# Matches between image 10 and 22: 181
# Matches between image 10 and 23: 154
# Matches between image 10 and 24: 172
# Matches between image 10 and 25: 158
# Matches between image 10 and 26: 153
# Matches between image 10 and 27: 173
# Matches between image 10 and 28: 189
# Matches between image 10 and 29: 189
# Matches between image 10 and 30: 222
# Matches between image 10 and 31: 177
# Matches between image 11 and 12: 336
# Matches between image 11 and 13: 251
# Matches between image 11 and 14: 309
# Matches between image 11 and 15: 252
# Matches between image 11 and 16: 242
# Matches between image 11 and 17: 264
# Matches between image 11 and 18: 224
# Matches between image 11 and 19: 234
# Matches between image 11 and 20: 198
# Matches between image 11 and 21: 225
# Matches between image 11 and 22: 224
# Matches between image 11 and 23: 222
# Matches between image 11 and 24: 229
# Matches between image 11 and 25: 191
# Matches between image 11 and 26: 213
# Matches between image 11 and 27: 244
# Matches between image 11 and 28: 366
# Matches between image 11 and 29: 264
# Matches between image 11 and 30: 239
# Matches between image 11 and 31: 238
# Matches between image 12 and 13: 200
# Matches between image 12 and 14: 219
# Matches between image 12 and 15: 179
# Matches between image 12 and 16: 201
# Matches between image 12 and 17: 196
# Matches between image 12 and 18: 179
# Matches between image 12 and 19: 170
# Matches between image 12 and 20: 169
# Matches between image 12 and 21: 186
# Matches between image 12 and 22: 161
# Matches between image 12 and 23: 169
# Matches between image 12 and 24: 162
# Matches between image 12 and 25: 166
# Matches between image 12 and 26: 162
# Matches between image 12 and 27: 188
# Matches between image 12 and 28: 272
# Matches between image 12 and 29: 217
# Matches between image 12 and 30: 184
# Matches between image 12 and 31: 190
# Matches between image 13 and 14: 166
# Matches between image 13 and 15: 175
# Matches between image 13 and 16: 174
# Matches between image 13 and 17: 153
# Matches between image 13 and 18: 163
# Matches between image 13 and 19: 140
# Matches between image 13 and 20: 124
# Matches between image 13 and 21: 140
# Matches between image 13 and 22: 124
# Matches between image 13 and 23: 132
# Matches between image 13 and 24: 138
# Matches between image 13 and 25: 126
# Matches between image 13 and 26: 116
# Matches between image 13 and 27: 178
# Matches between image 13 and 28: 169
# Matches between image 13 and 29: 152
# Matches between image 13 and 30: 126
# Matches between image 13 and 31: 128
# Matches between image 14 and 15: 311
# Matches between image 14 and 16: 325
# Matches between image 14 and 17: 290
# Matches between image 14 and 18: 286
# Matches between image 14 and 19: 268
# Matches between image 14 and 20: 237
# Matches between image 14 and 21: 284
# Matches between image 14 and 22: 276
# Matches between image 14 and 23: 276
# Matches between image 14 and 24: 284
# Matches between image 14 and 25: 255
# Matches between image 14 and 26: 267
# Matches between image 14 and 27: 333
# Matches between image 14 and 28: 383
# Matches between image 14 and 29: 300
# Matches between image 14 and 30: 270
# Matches between image 14 and 31: 266
# Matches between image 15 and 16: 276
# Matches between image 15 and 17: 288
# Matches between image 15 and 18: 267
# Matches between image 15 and 19: 252
# Matches between image 15 and 20: 205
# Matches between image 15 and 21: 252
# Matches between image 15 and 22: 217
# Matches between image 15 and 23: 226
# Matches between image 15 and 24: 229
# Matches between image 15 and 25: 201
# Matches between image 15 and 26: 188
# Matches between image 15 and 27: 273
# Matches between image 15 and 28: 213
# Matches between image 15 and 29: 193
# Matches between image 15 and 30: 183
# Matches between image 15 and 31: 183
# Matches between image 16 and 17: 223
# Matches between image 16 and 18: 229
# Matches between image 16 and 19: 215
# Matches between image 16 and 20: 160
# Matches between image 16 and 21: 208
# Matches between image 16 and 22: 187
# Matches between image 16 and 23: 161
# Matches between image 16 and 24: 189
# Matches between image 16 and 25: 175
# Matches between image 16 and 26: 153
# Matches between image 16 and 27: 246
# Matches between image 16 and 28: 203
# Matches between image 16 and 29: 170
# Matches between image 16 and 30: 164
# Matches between image 16 and 31: 165
# Matches between image 17 and 18: 246
# Matches between image 17 and 19: 257
# Matches between image 17 and 20: 181
# Matches between image 17 and 21: 257
# Matches between image 17 and 22: 222
# Matches between image 17 and 23: 229
# Matches between image 17 and 24: 233
# Matches between image 17 and 25: 209
# Matches between image 17 and 26: 189
# Matches between image 17 and 27: 253
# Matches between image 17 and 28: 197
# Matches between image 17 and 29: 181
# Matches between image 17 and 30: 177
# Matches between image 17 and 31: 181
# Matches between image 18 and 19: 176
# Matches between image 18 and 20: 123
# Matches between image 18 and 21: 158
# Matches between image 18 and 22: 146
# Matches between image 18 and 23: 159
# Matches between image 18 and 24: 152
# Matches between image 18 and 25: 137
# Matches between image 18 and 26: 127
# Matches between image 18 and 27: 187
# Matches between image 18 and 28: 151
# Matches between image 18 and 29: 120
# Matches between image 18 and 30: 118
# Matches between image 18 and 31: 120
# Matches between image 19 and 20: 143
# Matches between image 19 and 21: 224
# Matches between image 19 and 22: 186
# Matches between image 19 and 23: 193
# Matches between image 19 and 24: 207
# Matches between image 19 and 25: 162
# Matches between image 19 and 26: 165
# Matches between image 19 and 27: 192
# Matches between image 19 and 28: 162
# Matches between image 19 and 29: 146
# Matches between image 19 and 30: 149
# Matches between image 19 and 31: 114
# Matches between image 20 and 21: 562
# Matches between image 20 and 22: 637
# Matches between image 20 and 23: 575
# Matches between image 20 and 24: 567
# Matches between image 20 and 25: 637
# Matches between image 20 and 26: 653
# Matches between image 20 and 27: 551
# Matches between image 20 and 28: 559
# Matches between image 20 and 29: 555
# Matches between image 20 and 30: 523
# Matches between image 20 and 31: 538
# Matches between image 21 and 22: 411
# Matches between image 21 and 23: 374
# Matches between image 21 and 24: 466
# Matches between image 21 and 25: 380
# Matches between image 21 and 26: 336
# Matches between image 21 and 27: 383
# Matches between image 21 and 28: 343
# Matches between image 21 and 29: 311
# Matches between image 21 and 30: 313
# Matches between image 21 and 31: 312
# Matches between image 22 and 23: 384
# Matches between image 22 and 24: 398
# Matches between image 22 and 25: 421
# Matches between image 22 and 26: 383
# Matches between image 22 and 27: 324
# Matches between image 22 and 28: 319
# Matches between image 22 and 29: 290
# Matches between image 22 and 30: 298
# Matches between image 22 and 31: 300
# Matches between image 23 and 24: 212
# Matches between image 23 and 25: 181
# Matches between image 23 and 26: 164
# Matches between image 23 and 27: 164
# Matches between image 23 and 28: 139
# Matches between image 23 and 29: 131
# Matches between image 23 and 30: 134
# Matches between image 23 and 31: 135
# Matches between image 24 and 25: 289
# Matches between image 24 and 26: 253
# Matches between image 24 and 27: 252
# Matches between image 24 and 28: 254
# Matches between image 24 and 29: 215
# Matches between image 24 and 30: 223
# Matches between image 24 and 31: 216
# Matches between image 25 and 26: 500
# Matches between image 25 and 27: 367
# Matches between image 25 and 28: 361
# Matches between image 25 and 29: 366
# Matches between image 25 and 30: 348
# Matches between image 25 and 31: 337
# Matches between image 26 and 27: 310
# Matches between image 26 and 28: 327
# Matches between image 26 and 29: 344
# Matches between image 26 and 30: 344
# Matches between image 26 and 31: 321
# Matches between image 27 and 28: 242
# Matches between image 27 and 29: 220
# Matches between image 27 and 30: 209
# Matches between image 27 and 31: 211
# Matches between image 28 and 29: 377
# Matches between image 28 and 30: 343
# Matches between image 28 and 31: 339
# Matches between image 29 and 30: 242
# Matches between image 29 and 31: 225
# Matches between image 30 and 31: 195
# Selected initial pair: Image 1 and 9 with 1317 matches
# Essential Matrix inliers: 1317
# Recovered pose: 0 points in front of cameras
# Triangulated 1317 3D points.
# Intermediate point cloud saved to ./sfm_output/point_cloud_2view.ply
# Adding Image 20 with 1787 correspondences.
# Image 20 registered successfully.
# Intermediate point cloud saved to ./sfm_output/point_cloud_3view.ply
# Adding Image 22 with 1674 correspondences.
# Image 22 registered successfully.
# Intermediate point cloud saved to ./sfm_output/point_cloud_4view.ply
# Adding Image 25 with 1618 correspondences.
# Image 25 registered successfully.
# Intermediate point cloud saved to ./sfm_output/point_cloud_5view.ply
# Adding Image 2 with 1517 correspondences.
# Image 2 registered successfully.
# Intermediate point cloud saved to ./sfm_output/point_cloud_6view.ply
# Adding Image 26 with 1510 correspondences.
# Image 26 registered successfully.
# Intermediate point cloud saved to ./sfm_output/point_cloud_7view.ply
# Adding Image 17 with 1484 correspondences.
# Image 17 registered successfully.
# Intermediate point cloud saved to ./sfm_output/point_cloud_8view.ply
# Adding Image 12 with 1469 correspondences.
# Image 12 registered successfully.
# Intermediate point cloud saved to ./sfm_output/point_cloud_9view.ply
# Adding Image 14 with 1449 correspondences.
# Image 14 registered successfully.
# Intermediate point cloud saved to ./sfm_output/point_cloud_10view.ply
# Adding Image 24 with 1436 correspondences.
# Image 24 registered successfully.
# Intermediate point cloud saved to ./sfm_output/point_cloud_11view.ply
# Adding Image 21 with 1435 correspondences.
# Image 21 registered successfully.
# Intermediate point cloud saved to ./sfm_output/point_cloud_12view.ply
# Adding Image 16 with 1425 correspondences.
# Image 16 registered successfully.
# Intermediate point cloud saved to ./sfm_output/point_cloud_13view.ply
# Adding Image 10 with 1421 correspondences.
# Image 10 registered successfully.
# Intermediate point cloud saved to ./sfm_output/point_cloud_14view.ply
# Adding Image 15 with 1421 correspondences.
# Image 15 registered successfully.
# Intermediate point cloud saved to ./sfm_output/point_cloud_15view.ply
# Adding Image 27 with 1419 correspondences.
# Image 27 registered successfully.
# Intermediate point cloud saved to ./sfm_output/point_cloud_16view.ply
# Adding Image 11 with 1415 correspondences.
# Image 11 registered successfully.
# Intermediate point cloud saved to ./sfm_output/point_cloud_17view.ply
# Adding Image 29 with 1414 correspondences.
# Image 29 registered successfully.
# Intermediate point cloud saved to ./sfm_output/point_cloud_18view.ply
# Adding Image 19 with 1412 correspondences.
# PnP failed for Image 19. Removing from candidates.
# Adding Image 13 with 1398 correspondences.
# Image 13 registered successfully.
# Intermediate point cloud saved to ./sfm_output/point_cloud_19view.ply
# Adding Image 28 with 1397 correspondences.
# Image 28 registered successfully.
# Intermediate point cloud saved to ./sfm_output/point_cloud_20view.ply
# Adding Image 18 with 1396 correspondences.
# Image 18 registered successfully.
# Intermediate point cloud saved to ./sfm_output/point_cloud_21view.ply
# Adding Image 30 with 1392 correspondences.
# Image 30 registered successfully.
# Intermediate point cloud saved to ./sfm_output/point_cloud_22view.ply
# Adding Image 23 with 1367 correspondences.
# Image 23 registered successfully.
# Intermediate point cloud saved to ./sfm_output/point_cloud_23view.ply
# Adding Image 31 with 1362 correspondences.
# Image 31 registered successfully.
# Intermediate point cloud saved to ./sfm_output/point_cloud_24view.ply
# Adding Image 3 with 1140 correspondences.
# Image 3 registered successfully.
# Intermediate point cloud saved to ./sfm_output/point_cloud_25view.ply
# Adding Image 5 with 1071 correspondences.
# Image 5 registered successfully.
# Intermediate point cloud saved to ./sfm_output/point_cloud_26view.ply
# Adding Image 4 with 1048 correspondences.
# Image 4 registered successfully.
# Intermediate point cloud saved to ./sfm_output/point_cloud_27view.ply
# Adding Image 6 with 880 correspondences.
# PnP failed for Image 6. Removing from candidates.
# Adding Image 8 with 859 correspondences.
# Image 8 registered successfully.
# Intermediate point cloud saved to ./sfm_output/point_cloud_28view.ply
# Adding Image 7 with 846 correspondences.
# Image 7 registered successfully.
# Intermediate point cloud saved to ./sfm_output/point_cloud_29view.ply
# Adding Image 0 with 315 correspondences.
# PnP failed for Image 0. Removing from candidates.
# Final colored point cloud saved to ./sfm_output/point_cloud_final.ply
# Saved ply for unregistered image 0 as ./sfm_output/point_cloud_1view_failed.ply
# Saved ply for registered image 1 as ./sfm_output/point_cloud_2view.ply
# Saved ply for registered image 2 as ./sfm_output/point_cloud_3view.ply
# Saved ply for registered image 3 as ./sfm_output/point_cloud_4view.ply
# Saved ply for registered image 4 as ./sfm_output/point_cloud_5view.ply
# Saved ply for registered image 5 as ./sfm_output/point_cloud_6view.ply
# Saved ply for unregistered image 6 as ./sfm_output/point_cloud_7view_failed.ply
# Saved ply for registered image 7 as ./sfm_output/point_cloud_8view.ply
# Saved ply for registered image 8 as ./sfm_output/point_cloud_9view.ply
# Saved ply for registered image 9 as ./sfm_output/point_cloud_10view.ply
# Saved ply for registered image 10 as ./sfm_output/point_cloud_11view.ply
# Saved ply for registered image 11 as ./sfm_output/point_cloud_12view.ply
# Saved ply for registered image 12 as ./sfm_output/point_cloud_13view.ply
# Saved ply for registered image 13 as ./sfm_output/point_cloud_14view.ply
# Saved ply for registered image 14 as ./sfm_output/point_cloud_15view.ply
# Saved ply for registered image 15 as ./sfm_output/point_cloud_16view.ply
# Saved ply for registered image 16 as ./sfm_output/point_cloud_17view.ply
# Saved ply for registered image 17 as ./sfm_output/point_cloud_18view.ply
# Saved ply for registered image 18 as ./sfm_output/point_cloud_19view.ply
# Saved ply for unregistered image 19 as ./sfm_output/point_cloud_20view_failed.ply
# Saved ply for registered image 20 as ./sfm_output/point_cloud_21view.ply
# Saved ply for registered image 21 as ./sfm_output/point_cloud_22view.ply
# Saved ply for registered image 22 as ./sfm_output/point_cloud_23view.ply
# Saved ply for registered image 23 as ./sfm_output/point_cloud_24view.ply
# Saved ply for registered image 24 as ./sfm_output/point_cloud_25view.ply
# Saved ply for registered image 25 as ./sfm_output/point_cloud_26view.ply
# Saved ply for registered image 26 as ./sfm_output/point_cloud_27view.ply
# Saved ply for registered image 27 as ./sfm_output/point_cloud_28view.ply
# Saved ply for registered image 28 as ./sfm_output/point_cloud_29view.ply
# Saved ply for registered image 29 as ./sfm_output/point_cloud_30view.ply
# Saved ply for registered image 30 as ./sfm_output/point_cloud_31view.ply
# Saved ply for registered image 31 as ./sfm_output/point_cloud_32view.ply
#
# SfM process finished (without bundle adjustment, full ply saving for all images).

# %%
import open3d as o3d

# PLY 파일 경로
ply_file_path = "/home/najo/NAS/Computer_Vision/data/output_ply_by_process/step_0031_map.ply"

# PLY 파일 로드
pcd = o3d.io.read_point_cloud(ply_file_path)
print(f"불러온 포인트 클라우드의 포인트 수: {len(pcd.points)}")

# 포인트 클라우드 시각화 (창 내 'q' 키로 종료)
o3d.visualization.draw_geometries([pcd], window_name="PLY 파일 시각화")
# Out:
# 불러온 포인트 클라우드의 포인트 수: 43
# [Open3D WARNING] GLFW Error: Failed to detect any supported platform
# [Open3D WARNING] GLFW initialized for headless rendering.
# [Open3D WARNING] GLFW Error: OSMesa: Library not found
# [Open3D WARNING] Failed to create window
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
